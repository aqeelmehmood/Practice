# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("My_Data1.csv")

# %%
df
# Out:
#     Data
# 0    567
# 1    572
# 2    572
# 3    589
# 4    614
# ..   ...
# 75   843
# 76   850
# 77   875
# 78   879
# 79   897
#
# [80 rows x 1 columns]

# %%
m=df.mean()

# %%
s=df.std()

# %%
df=df-m

# %%
df.mean()
# Out:
# Data    6.536993e-14
# dtype: float64

# %%
df = df / s
df
# Out:
#         Data
# 0  -2.377515
# 1  -2.309986
# 2  -2.309986
# 3  -2.080389
# 4  -1.742745
# ..       ...
# 75  1.350066
# 76  1.444606
# 77  1.782250
# 78  1.836273
# 79  2.079376
#
# [80 rows x 1 columns]

# %%
df1=df.mean()
df1
# Out:
# Data   -3.053113e-16
# dtype: float64

# %%
df2=df.std()

# %%
df2
# Out:
# Data    1.0
# dtype: float64

# %%
df2=np.random.normal()

# %%
df3=np.random.rand(1,1000)*100

# %%
df3
# Out:
# array([[22.27288703,  7.33866235, 38.70149357, 83.78650823, 39.48297476,
#         59.63710122, 69.26805326, 13.05680582, 97.09787452, 64.54769407,
#          8.80990114,  1.98433105,  7.91171509, 45.44021056, 51.25086407,
#         40.70749906, 39.31881733, 29.14416651, 16.16381489, 12.56092073,
#          3.77909191, 72.73596644, 82.39057874, 97.89934785, 56.21493464,
#         66.24157394, 54.60563329, 61.29076077, 72.62984021, 11.91731876,
#         50.59617415, 83.60912718, 87.22229811, 20.15328673, 45.02896714,
#         41.01443276, 69.57531697, 14.16921821, 43.50579864, 94.7435496 ,
#          2.35819732, 90.39187162, 56.8759968 , 26.96959334, 68.95440844,
#         29.38808191, 88.64165658, 83.8539889 , 23.41352763, 37.79874099,
#         33.12203115, 90.82421737, 53.15962598,  6.66814495, 77.07423551,
#         18.53722407,  6.38627355, 52.13142104, 89.03917612, 38.69560937,
#          9.32405858, 92.72172774, 92.05712428, 85.39633202, 34.53806288,
# ...

# %%
df3.mean()
# Out:
# 49.01194107134847

# %%
df3.std()
# Out:
# 28.261159817188314

# %%
df3.sample(n=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-e84cedc2251f> in <module>
# ----> 1 df3.sample(n=1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sample'
